# %%
import pandas as pd

# %%
main_df = pd.read_excel("Data Sheet.xlsx", "Main DF")

# %%
main_df
# Out:
#        zip    county  latitude  longitude  irs_estimated_population  \
# 0    12007    Albany     42.46     -73.93                       160
# 1    12009    Albany     42.70     -74.03                      7260
# 2    12023    Albany     42.62     -74.13                      1870
# 3    12041    Albany     42.58     -73.95                       470
# 4    12045    Albany     42.48     -73.80                       583
# ..     ...       ...       ...        ...                       ...
# 509  12980  Franklin     44.49     -74.53                      1010
# 510  12983  Franklin     44.32     -74.13                      5880
# 511  12986  Franklin     44.23     -74.46                      4490
# 512  12989  Franklin     44.52     -74.09                       790
# 513  12995  Franklin     44.73     -74.26                       111
#
#      percent_va_enrollees  mult_factor  VA_Enrollees  has_VA_facility  \
# 0                0.076310      0.40363             5            False
# ...

# %%
exist_fac = main_df.zip.unique().tolist()
potential_partnerships = main_df.zip.unique().tolist()
potential_new_sites = main_df.zip.unique().tolist()

# %%
exist_fac
# Out:
# [12007,
#  12009,
#  12023,
#  12041,
#  12045,
#  12046,
#  12047,
#  12054,
#  12055,
#  12059,
#  12067,
#  12077,
#  12084,
#  12085,
#  12107,
#  12110,
#  12120,
#  12128,
#  12143,
#  12147,
#  12158,
#  12159,
#  12161,
#  12183,
#  12186,
#  12189,
#  12193,
#  12201,
#  12202,
#  12203,
#  12204,
#  12205,
#  12206,
#  12207,
#  12208,
#  12209,
#  12210,
#  12211,
#  12212,
#  12214,
#  12220,
#  12222,
#  12223,
#  12224,
#  12225,
#  12226,
#  12227,
#  12228,
#  12229,
#  12230,
#  12231,
#  12232,
#  12233,
#  12234,
#  12235,
#  12236,
#  12237,
#  12238,
#  12239,
#  12240,
#  12241,
#  12242,
#  12243,
#  12244,
#  12245,
#  12246,
#  12247,
#  12248,
#  12249,
#  12250,
#  12252,
#  12255,
#  12256,
#  12257,
#  12260,
#  12261,
#  12288,
#  12469,
#  12008,
#  12053,
#  12056,
#  12137,
#  12141,
#  12150,
#  12301,
#  12302,
#  12303,
#  12304,
#  12305,
#  12306,
#  12307,
#  12308,
#  12309,
#  12325,
#  12345,
#  12010,
#  12016,
#  12068,
#  12069,
#  12070,
# ...
